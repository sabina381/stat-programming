# %% [markdown]
# ### 통계학과 2229022 이승연

# %% [markdown]
# # Exercise 1
# # Markdown Practice.
# ## Introduction
# __Markdown is__ a lightweight markup language that you can use to add *formatting* elements to plaintext text documents.

# %% [markdown]
# # Exercise 2
#
# 1. Python
# 2. R
# 3. C++
#
# - Watching baseball game (my favorite team is Lotte Giants)
# - Playing a game
# - Knitting

# %% [markdown]
# # Exercise 3
#
# > The best way to predict the future is to invent it.
#
# ```py
# print("Hello, world!")
#
# ```

# %% [markdown]
# # Exercise 4
# $x={-b\pm\sqrt{b^2-4ac}\over 2a}$
#
# $$
# \int_{0}^{1}x^2\, dx
# $$

# %% [markdown]
# # Exercise 5
#
# | Programming Language | Difficulty (1~5) |
# | - | - |
# | Python | 3 |
# | R | 1 |
# | C++ | 5 |

# %% [markdown]
# # Exercise 6
#
# ![image.png](data:image/png;base64,...)
